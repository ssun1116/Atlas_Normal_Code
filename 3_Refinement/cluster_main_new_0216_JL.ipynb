# %%
import scanpy as sc
import os,sys,glob
import pandas as pd
import numpy as np
import anndata as ad
import matplotlib as mlt
import matplotlib.pyplot as plt

# %%
adata = sc.read_h5ad("Data/Output_240215_adata_scvi_random_sampleID.h5ad")

# %%
# cluster main dictionary
leiden_0p6_cluster_main_dict_new = {
    'Astro': ['2', '27'],
    'Ext': ['12', '29', '25', '16', '17', '14', '36', '22', '5', '10', '1', '15', '34', '35'],
    'Inh': ['21', '28', '8', '31', '6', '7', '19', '20', '23'],
    'Micro': ['39', '13'],
    'Neuroblast': ['11','33','3','24','26' ],
    'OPC': ['9', '32'],
    'Oligo': ['0', '38'],
    'Others': ['30','40'],
    'RG': ['4', '18', '37']
}

# reversed dictionary
reversed_new = {}
for value, keys in leiden_0p6_cluster_main_dict_new.items():
    for key in keys:
        reversed_new[key] = value

# %%
adata.obs['Cell Type'] = adata.obs["leiden_0.6"].map(reversed_new)
adata.obs['Cell Type']
# Out:
# 10X119_2:TCGTACCCAGACAAAT              RG
# 10X119_2:AGAGCGACACCGCTAG              RG
# 10X119_2:AAGGAGCGTTGAGTTC      Neuroblast
# 10X119_2:ATAGACCAGGGTGTTG              RG
# 10X119_2:TTAGGCATCCGAACGC              RG
#                                   ...
# hsDG99HC_TTTGTTGGTTCATCTT-1         Micro
# hsDG99HC_TTTGTTGTCATCTATC-1         Oligo
# hsDG99HC_TTTGTTGTCCTCGATC-1           Ext
# hsDG99HC_TTTGTTGTCGTTAGAC-1         Oligo
# hsDG99HC_TTTGTTGTCTCGTCAC-1         Astro
# Name: Cell Type, Length: 393060, dtype: object

# %%
sc.pl.umap(adata, color='Cell Type', save = True)
# Out:
# /home/esoap0926/anaconda3/envs/sc/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# WARNING: saving figure to file figures/umap.pdf

# %%
adata.write_h5ad("Data/Output_240215_adata_scvi_random_sampleID.h5ad")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 adata.write_h5ad("Data/Output_240215_adata_scvi_random_sampleID.h5ad")
#
# File ~/anaconda3/envs/sc/lib/python3.8/site-packages/anndata/_core/anndata.py:1951, in AnnData.write_h5ad(self, filename, compression, compression_opts, as_dense)
#    1948 if filename is None:
#    1949     filename = self.filename
# -> 1951 _write_h5ad(
#    1952     Path(filename),
#    1953     self,
#    1954     compression=compression,
#    1955     compression_opts=compression_opts,
#    1956     as_dense=as_dense,
#    1957 )
#    1959 if self.isbacked:
#    1960     self.file.filename = filename
#
# File ~/anaconda3/envs/sc/lib/python3.8/site-packages/anndata/_io/h5ad.py:67, in write_h5ad(filepath, adata, as_dense, dataset_kwargs, **kwargs)
#      64 if adata.isbacked:  # close so that we can reopen below
#      65     adata.file.close()
# ---> 67 with h5py.File(filepath, mode) as f:
#      68     # TODO: Use spec writing system for this
#      69     # Currently can't use write_dispatched here because this function is also called to do an
#      70     # inplace update of a backed object, which would delete "/"
#      71     f = f["/"]
#      72     f.attrs.setdefault("encoding-type", "anndata")
#
# File ~/anaconda3/envs/sc/lib/python3.8/site-packages/h5py/_hl/files.py:424, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, **kwds)
#     422 with phil:
#     423     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0, **kwds)
# --> 424     fid = make_fid(name, mode, userblock_size,
#     425                    fapl, fcpl=make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     426                    fs_persist=fs_persist, fs_threshold=fs_threshold),
#     427                    swmr=swmr)
#     429 if isinstance(libver, tuple):
#     430     self._libver = libver
#
# File ~/anaconda3/envs/sc/lib/python3.8/site-packages/h5py/_hl/files.py:196, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     194     fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     195 elif mode == 'w':
# --> 196     fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#     197 elif mode == 'a':
#     198     # Open in append mode (read/write).
#     199     # If that fails, create a new file only if it won't clobber an
#     200     # existing one (ACC_EXCL)
#     201     try:
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:116, in h5py.h5f.create()
#
# OSError: Unable to create file (unable to open file: name = 'Data/Output_240215_adata_scvi_random_sampleID.h5ad', errno = 13, error message = 'Permission denied', flags = 13, o_flags = 242)
