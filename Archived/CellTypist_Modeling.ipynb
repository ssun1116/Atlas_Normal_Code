# %%
import celltypist
from celltypist import models

# %%
import scanpy as sc
import os,sys,glob
import pandas as pd
import numpy as np
import anndata as ad
import matplotlib.pyplot as plt

import seaborn as sns
from matplotlib.colors import ListedColormap

import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42

sc.settings.n_jobs = 30
sc.set_figure_params(figsize=(4,4), vector_friendly = True)
# %config InlineBackend.print_figure_kwargs={'facecolor' : "w"}
# %config InlineBackend.figure_format='retina'

# %%
adata = sc.read_h5ad("Data/Output_230911_adata_scvi_random_sampleID_annot.h5ad") # 12m

# %%
adata.X = adata.layers["logcounts"].copy() # 8.4s # adata.X must be logcounts value

# %% [markdown]
# # CellTypist modelling using all genes

# %%
adata # 0.0s
# Out:
# AnnData object with n_obs × n_vars = 393060 × 49133
#     obs: 'batch', 'sampleID', 'Age', 'Assay', 'Stage', 'Race', 'PMI', 'Hemisphere', 'Library', 'Brain_Region', 'Dataset', 'Sex', 'Diagnosis', 'DF_classification', 'cluster_original', 'cluster_main', 'n_genes', 'Stage2', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'doublet_scores', 'predicted_doublets', '_scvi_batch', '_scvi_labels', 'leiden_scvi', 'leiden_0.5', 'leiden_0.7', 'leiden_1.0', 'cluster_main2', 'Brain_Region2', 'Brain_Region3', 'Brain_Region_Unit', 'cluster_number'
#     uns: 'Brain_Region3_colors', 'Stage2_colors', 'cluster_main2_colors', 'leiden_scvi_colors', 'log1p'
#     obsm: 'X_scVI_sampleID', 'X_umap', '_scvi_extra_categorical_covs'
#     layers: 'counts', 'logcounts', 'scaled'

# %%
new_model = celltypist.train(adata, 
                             labels = adata.obs["cluster_number"], 
                             check_expression = False, 
                             n_jobs = 40, use_SGD = True) # 90~m
# Out:
# 🍳 Preparing data before training
# ✂️ 13046 non-expressed genes are filtered out
# ⚖️ Scaling input data
# 🏋️ Training data using SGD logistic regression
# ⚠️ Warning: it may take a long time to train this dataset with 393060 cells and 36087 genes, try to downsample cells and/or restrict genes to a subset (e.g., hvgs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 4
#       1 #Training a CellTypist model with only subset of genes (e.g., highly variable genes).
#       2 #Restricting the input to a subset of genes can accelerate the training process.
#       3 #Use `AnnData` here as an example.
# ----> 4 new_model = celltypist.train(adata, labels = adata.obs["cluster_number"], check_expression = False, n_jobs = 40, use_SGD = True)
#
# File ~/anaconda3/envs/BrainAtlas/lib/python3.8/site-packages/celltypist/train.py:327, in train(X, labels, genes, transpose_input, with_mean, check_expression, C, solver, max_iter, n_jobs, use_SGD, alpha, mini_batch, batch_number, batch_size, epochs, balance_cell_type, feature_selection, top_genes, date, details, url, source, version, **kwargs)
#     325 #classifier
#     326 if use_SGD or feature_selection:
# --> 327     classifier = _SGDClassifier(indata = indata, labels = labels, alpha = alpha, max_iter = max_iter, n_jobs = n_jobs, mini_batch = mini_batch, batch_number = batch_number, batch_size = batch_size, epochs = epochs, balance_cell_type = balance_cell_type, **kwargs)
#     328 else:
#     329     classifier = _LRClassifier(indata = indata, labels = labels, C = C, solver = solver, max_iter = max_iter, n_jobs = n_jobs, **kwargs)
#
# File ~/anaconda3/envs/BrainAtlas/lib/python3.8/site-packages/celltypist/train.py:135, in _SGDClassifier(indata, labels, alpha, max_iter, n_jobs, mini_batch, batch_number, batch_size, epochs, balance_cell_type, **kwargs)
#     133     if (len(labels) > 100000) and (indata.shape[1] > 10000):
#     134         logger.warn(f"⚠️ Warning: it may take a long time to train this dataset with {len(labels)} cells and {indata.shape[1]} genes, try to downsample cells and/or restrict genes to a subset (e.g., hvgs)")
# --> 135     classifier.fit(indata, labels)
#     136 else:
#     137     logger.info(f"🏋️ Training data using mini-batch SGD logistic regression")
#
# File ~/anaconda3/envs/BrainAtlas/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:883, in BaseSGDClassifier.fit(self, X, y, coef_init, intercept_init, sample_weight)
#     855 def fit(self, X, y, coef_init=None, intercept_init=None, sample_weight=None):
#     856     """Fit linear model with Stochastic Gradient Descent.
#     857
#     858     Parameters
#    (...)
#     881         Returns an instance of self.
#     882     """
# --> 883     return self._fit(
#     884         X,
#     885         y,
#     886         alpha=self.alpha,
#     887         C=1.0,
#     888         loss=self.loss,
#     889         learning_rate=self.learning_rate,
#     890         coef_init=coef_init,
#     891         intercept_init=intercept_init,
#     892         sample_weight=sample_weight,
#     893     )
#
# File ~/anaconda3/envs/BrainAtlas/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:677, in BaseSGDClassifier._fit(self, X, y, alpha, C, loss, learning_rate, coef_init, intercept_init, sample_weight)
#     674 # Clear iteration count for multiple call to fit.
#     675 self.t_ = 1.0
# --> 677 self._partial_fit(
#     678     X,
#     679     y,
#     680     alpha,
#     681     C,
#     682     loss,
#     683     learning_rate,
#     684     self.max_iter,
#     685     classes,
#     686     sample_weight,
#     687     coef_init,
#     688     intercept_init,
#     689 )
#     691 if (
#     692     self.tol is not None
#     693     and self.tol > -np.inf
#     694     and self.n_iter_ == self.max_iter
#     695 ):
#     696     warnings.warn(
#     697         "Maximum number of iteration reached before "
#     698         "convergence. Consider increasing max_iter to "
#     699         "improve the fit.",
#     700         ConvergenceWarning,
#     701     )
#
# File ~/anaconda3/envs/BrainAtlas/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:610, in BaseSGDClassifier._partial_fit(self, X, y, alpha, C, loss, learning_rate, max_iter, classes, sample_weight, coef_init, intercept_init)
#     608 # delegate to concrete training procedure
#     609 if n_classes > 2:
# --> 610     self._fit_multiclass(
#     611         X,
#     612         y,
#     613         alpha=alpha,
#     614         C=C,
#     615         learning_rate=learning_rate,
#     616         sample_weight=sample_weight,
#     617         max_iter=max_iter,
#     618     )
#     619 elif n_classes == 2:
#     620     self._fit_binary(
#     621         X,
#     622         y,
#    (...)
#     627         max_iter=max_iter,
#     628     )
#
# File ~/anaconda3/envs/BrainAtlas/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:754, in BaseSGDClassifier._fit_multiclass(self, X, y, alpha, C, learning_rate, sample_weight, max_iter)
#     752 random_state = check_random_state(self.random_state)
#     753 seeds = random_state.randint(MAX_INT, size=len(self.classes_))
# --> 754 result = Parallel(
#     755     n_jobs=self.n_jobs,
#     756     verbose=self.verbose,
#     757     **_joblib_parallel_args(require="sharedmem"),
#     758 )(
#     759     delayed(fit_binary)(
#     760         self,
#     761         i,
#     762         X,
#     763         y,
#     764         alpha,
#     765         C,
#     766         learning_rate,
#     767         max_iter,
#     768         self._expanded_class_weight[i],
#     769         1.0,
#     770         sample_weight,
#     771         validation_mask=validation_mask,
#     772         random_state=seed,
#     773     )
#     774     for i, seed in enumerate(seeds)
#     775 )
#     777 # take the maximum of n_iter_ over every binary fit
#     778 n_iter_ = 0.0
#
# File ~/anaconda3/envs/BrainAtlas/lib/python3.8/site-packages/joblib/parallel.py:1056, in Parallel.__call__(self, iterable)
#    1053     self._iterating = False
#    1055 with self._backend.retrieval_context():
# -> 1056     self.retrieve()
#    1057 # Make sure that we get a last message telling us we are done
#    1058 elapsed_time = time.time() - self._start_time
#
# File ~/anaconda3/envs/BrainAtlas/lib/python3.8/site-packages/joblib/parallel.py:935, in Parallel.retrieve(self)
#     933 try:
#     934     if getattr(self._backend, 'supports_timeout', False):
# --> 935         self._output.extend(job.get(timeout=self.timeout))
#     936     else:
#     937         self._output.extend(job.get())
#
# File ~/anaconda3/envs/BrainAtlas/lib/python3.8/multiprocessing/pool.py:765, in ApplyResult.get(self, timeout)
#     764 def get(self, timeout=None):
# --> 765     self.wait(timeout)
#     766     if not self.ready():
#     767         raise TimeoutError
#
# File ~/anaconda3/envs/BrainAtlas/lib/python3.8/multiprocessing/pool.py:762, in ApplyResult.wait(self, timeout)
#     761 def wait(self, timeout=None):
# --> 762     self._event.wait(timeout)
#
# File ~/anaconda3/envs/BrainAtlas/lib/python3.8/threading.py:558, in Event.wait(self, timeout)
#     556 signaled = self._flag
#     557 if not signaled:
# --> 558     signaled = self._cond.wait(timeout)
#     559 return signaled
#
# File ~/anaconda3/envs/BrainAtlas/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     300 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301     if timeout is None:
# --> 302         waiter.acquire()
#     303         gotit = True
#     304     else:
#
# KeyboardInterrupt:

# %%
#Write out the model.
new_model.write('test_all.pkl') #

# %% [markdown]
# # Celltypist modelling using HVG

# %%
adata_hvg = sc.read_h5ad("Data/Output_230907_adata_scvi_random_sampleID_hvg.h5ad")
adata_hvg # 1m
# Out:
# AnnData object with n_obs × n_vars = 393064 × 5000
#     obs: 'batch', 'sampleID', 'Age', 'Assay', 'Stage', 'Race', 'PMI', 'Hemisphere', 'Library', 'Brain_Region', 'Dataset', 'Sex', 'Diagnosis', 'DF_classification', 'cluster_original', 'cluster_main', 'n_genes', 'Stage2', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'doublet_scores', 'predicted_doublets', '_scvi_batch', '_scvi_labels', 'leiden_scvi', 'leiden_0.5', 'leiden_0.7', 'leiden_1.0'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'Dataset_colors', '_scvi_manager_uuid', '_scvi_uuid', 'cluster_main_colors', 'hvg', 'leiden', 'leiden_0.5_colors', 'leiden_0.7_colors', 'leiden_1.0_colors', 'leiden_scvi_colors', 'log1p', 'neighbors', 'umap'
#     obsm: 'X_scVI_sampleID', 'X_umap', '_scvi_extra_categorical_covs'
#     layers: 'counts', 'logcounts'
#     obsp: 'connectivities', 'distances'

# %%
adata_hvg.var.highly_variable.index
# Out:
# Index(['A1CF', 'A2M', 'A2ML1', 'A4GALT', 'AAMDC', 'AASS', 'ABAT', 'ABCA1',
#        'ABCA5', 'ABCA8',
#        ...
#        'ZNF844', 'ZNF90', 'ZNF98', 'ZNRF2', 'ZNRF3', 'ZRANB2-DT', 'ZRANB3',
#        'ZSCAN5A', 'ZSWIM5', 'ZWINT'],
#       dtype='object', name='new_gene', length=5000)

# %%
hvg_model = celltypist.train(adata[:,adata_hvg.var.highly_variable.index], 
                             labels = adata.obs["cluster_number"], 
                             check_expression = False, 
                             n_jobs = 40, use_SGD = True) # 20-25m
# Out:
# 🍳 Preparing data before training
# ⚖️ Scaling input data
# 🏋️ Training data using SGD logistic regression
# ✅ Model training done!

# %%
#Write out the model.
hvg_model.write('test_hvg.pkl') #

# %% [markdown]
# # Celltypist Annotation

# %%
adata_cancer = sc.read_h5ad("EGAD00001008811_SF3391_filtered_adata.h5ad")

# %%
adata_cancer
# Out:
# AnnData object with n_obs × n_vars = 5184 × 36601
#     obs: 'SampleID', 'Study', 'n_genes', 'n_counts', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'doublet_scores', 'predicted_doublets'
#     var: 'gene_ids', 'feature_types', 'genome', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %%
adata_cancer.layers["counts"] = adata_cancer.X.copy()
sc.pp.normalize_total(adata_cancer)
sc.pp.log1p(adata_cancer)
adata_cancer.layers["logcounts"] = adata_cancer.X.copy()

# %%
predictions = celltypist.annotate(adata_cancer, model = 'test_hvg.pkl', majority_voting = True) # 5s
# Out:
# ⚠️ Warning: invalid expression matrix, expect all genes and log1p normalized expression to 10000 counts per cell. The prediction result may not be accurate
# 🔬 Input data has 5184 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 4805 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 10
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!

# %%
# Get an `AnnData` with predicted labels embedded into the cell metadata columns.
adata_cancer_pre = predictions.to_adata()
adata_cancer_pre
# Out:
# AnnData object with n_obs × n_vars = 5184 × 36601
#     obs: 'SampleID', 'Study', 'n_genes', 'n_counts', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'doublet_scores', 'predicted_doublets', 'predicted_labels', 'over_clustering', 'majority_voting', 'conf_score'
#     var: 'gene_ids', 'feature_types', 'genome', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'log1p', 'neighbors', 'leiden'
#     obsm: 'X_pca'
#     layers: 'counts', 'logcounts'
#     obsp: 'connectivities', 'distances'

# %%
adata_cancer_pre.obs["majority_voting"].value_counts() # oligo, Astro, RG
# Out:
# C0    3253
# C2    1178
# C3     753
# Name: majority_voting, dtype: int64

# %%
adata_cancer2 = sc.pp.subsample(adata_cancer, fraction = 0.1, copy = True)

# %%
adata_cancer2
# Out:
# AnnData object with n_obs × n_vars = 518 × 36601
#     obs: 'SampleID', 'Study', 'n_genes', 'n_counts', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'doublet_scores', 'predicted_doublets'
#     var: 'gene_ids', 'feature_types', 'genome', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %%
adata_cancer2.layers["counts"] = adata_cancer2.X.copy()
sc.pp.normalize_total(adata_cancer2)
sc.pp.log1p(adata_cancer2)
adata_cancer2.layers["logcounts"] = adata_cancer2.X.copy()

# %%
predictions2 = celltypist.annotate(adata_cancer2, model = 'test_hvg.pkl', majority_voting = True) # 5s
# Out:
# ⚠️ Warning: invalid expression matrix, expect all genes and log1p normalized expression to 10000 counts per cell. The prediction result may not be accurate
# 🔬 Input data has 518 cells and 36601 genes
# 🔗 Matching reference genes in the model
# 🧬 4805 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 5
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!

# %%
# Get an `AnnData` with predicted labels embedded into the cell metadata columns.
adata_cancer2_pre = predictions2.to_adata()
adata_cancer2_pre
# Out:
# AnnData object with n_obs × n_vars = 518 × 36601
#     obs: 'SampleID', 'Study', 'n_genes', 'n_counts', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'doublet_scores', 'predicted_doublets', 'predicted_labels', 'over_clustering', 'majority_voting', 'conf_score'
#     var: 'gene_ids', 'feature_types', 'genome', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'log1p', 'neighbors', 'leiden'
#     obsm: 'X_pca'
#     layers: 'counts', 'logcounts'
#     obsp: 'connectivities', 'distances'

# %%
adata_cancer2_pre.obs["majority_voting"].value_counts()
# Out:
# C0    342
# C2    131
# C3     45
# Name: majority_voting, dtype: int64
