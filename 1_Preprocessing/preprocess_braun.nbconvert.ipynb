# %% [markdown]
# # Braun, Linnarson
#
# - https://www.biorxiv.org/content/10.1101/2022.10.24.513487v1

# %%
import sys
import numpy as np
import scanpy as sc
import h5py
import anndata
import scipy.sparse
import pandas as pd

# %%
# Load dataset
hdf=h5py.File('/home/sonic/scData/HCA_Braun/HumanFetalBrainPool.h5','r')
mat=hdf['shoji']['Expression']

# %%
# make adata and then add other metadata as adata.obs
expr = hdf['shoji']['Expression'][:1665937]
a = sc.AnnData(expr)
# Out:
# /tmp/ipykernel_325681/1099711945.py:3: FutureWarning: X.dtype being converted to np.float32 from uint16. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   a = sc.AnnData(expr)

# %%
del expr

# %%
# extract cell names and gene names and add to adata
genes = np.array(hdf['shoji']['Gene'][:], dtype=str)
cells = np.array(hdf['shoji']['CellID'][:1665937], dtype=str)

# %%
hdf['shoji'].keys()
# Out:
# <KeysViewHDF5 ['Accession', 'Age', 'AnnotationDefinition', 'AnnotationDescription', 'AnnotationName', 'AnnotationPosterior', 'CellClass', 'CellCycleFraction', 'CellID', 'Chemistry', 'Chromosome', 'Class', 'ClusterID', 'Clusters', 'Donor', 'DoubletFlag', 'DoubletScore', 'DropletClass', 'Embedding', 'End', 'Enrichment', 'Expression', 'Factors', 'Gene', 'GeneNonzeros', 'GeneTotalUMIs', 'Linkage', 'Loadings', 'ManifoldIndices', 'ManifoldRadius', 'ManifoldWeights', 'MeanAge', 'MeanCellCycle', 'MeanDoubletScore', 'MeanExpression', 'MeanTotalUMI', 'MitoFraction', 'NCells', 'NGenes', 'Nonzeros', 'OverallTotalUMIs', 'PrevClusters', 'Recipe', 'Region', 'SampleID', 'SelectedFeatures', 'Sex', 'Species', 'Start', 'StdevExpression', 'Subdivision', 'Subregion', 'Tissue', 'TopLevelCluster', 'TotalUMIs', 'Trinaries', 'UnsplicedFraction', 'ValidCells', 'ValidGenes']>

# %%
# Barcodes

# %%
# Add meta information
a.obs['CellID'] = cells
a.obs['Age'] = np.array(hdf['shoji']['Age'][:], dtype='float32')
a.obs['Assay'] = np.array(hdf['shoji']['Chemistry'][:], dtype=str)
a.obs.loc[a.obs['Assay'] == 'v3', 'Assay'] = "10x Chromium 3' v3"
a.obs.loc[a.obs['Assay'] == 'v2', 'Assay'] = "10x Chromium 3' v2"
a.obs['cluster_original'] = np.array(hdf['shoji']['CellClass'][:], dtype=str)
a.obs['batch'] = np.array(hdf['shoji']['Donor'][:], dtype=str)
a.obs['sampleID'] = np.array(hdf['shoji']['SampleID'][:], dtype=str)
a.obs['Region'] = np.array(hdf['shoji']['Region'][:], dtype=str)
a.obs['Sex'] = np.array(hdf['shoji']['Sex'][:], dtype=str)
a.obs.loc[a.obs['Sex'] == '', 'Sex'] = 'Unknown'
a.obs['Subdivision'] = np.array(hdf['shoji']['Subdivision'][:], dtype=str)
a.obs['Subregion'] = np.array(hdf['shoji']['Subregion'][:], dtype=str)
a.obs['Tissue'] = np.array(hdf['shoji']['Tissue'][:], dtype=str)
a.obs['Race'] = 'Unknown'
a.obs['Stage'] = 'Fetal'
a.obs['PMI'] = 'Unknown'
a.obs['Hemisphere'] = 'A'
a.obs['Library'] = 'scRNA'

# Update information
a.obs['cluster_main'] = 'Unknown'
a.obs.loc[a.obs['cluster_original'] == 'Oligo', 'cluster_main'] = 'OD'
a.obs.loc[a.obs['cluster_original'] == 'Erythrocyte', 'cluster_main'] = 'Others'
a.obs.loc[a.obs['cluster_original'] == 'Fibroblast', 'cluster_main'] = 'Others'
a.obs.loc[a.obs['cluster_original'] == 'Vascular', 'cluster_main'] = 'Others'
a.obs.loc[a.obs['cluster_original'] == 'Placodes', 'cluster_main'] = 'Others'

a.obs.loc[a.obs['cluster_original'] == 'Neuroblast', 'cluster_main'] = 'Neuroblast'
a.obs.loc[a.obs['cluster_original'] == 'Glioblast', 'cluster_main'] = 'Glioblast'
a.obs.loc[a.obs['cluster_original'] == 'Neural crest', 'cluster_main'] = 'Neural crest'

a.obs.loc[a.obs['cluster_original'] == 'Radial glia', 'cluster_main'] = 'RG'
a.obs.loc[a.obs['cluster_original'] == 'Immune', 'cluster_main'] = 'MG'
a.obs.loc[a.obs['cluster_original'] == 'Neuron', 'cluster_main'] = 'Ext'
a.obs.loc[a.obs['cluster_original'] == 'Neuronal IPC', 'cluster_main'] = 'Ext'

# Set up index
a.obs = a.obs.set_index('CellID')

# %%
a.obs
# Out:
#                            Age               Assay cluster_original    batch  \
# CellID
# 10X89_1:AAACGGGAGGCTACGA   8.0  10x Chromium 3' v2      Erythrocyte  BRC2006
# 10X89_1:ACGAGGAAGAGCCTAG   8.0  10x Chromium 3' v2      Erythrocyte  BRC2006
# 10X89_1:ACGCCAGTCGATAGAA   8.0  10x Chromium 3' v2      Erythrocyte  BRC2006
# 10X89_1:CCGGGATCAGACACTT   8.0  10x Chromium 3' v2      Erythrocyte  BRC2006
# 10X89_1:CGACTTCTCCCACTTG   8.0  10x Chromium 3' v2      Erythrocyte  BRC2006
# ...                        ...                 ...              ...      ...
# 10X302_7:AGAGAATAGAGGATCC  7.0  10x Chromium 3' v3         Vascular  XDD:398
# 10X302_8:AAGCCATTCCACCTCA  7.0  10x Chromium 3' v3         Vascular  XDD:398
# 10X302_8:ACGGTTAGTTAGGCCC  7.0  10x Chromium 3' v3         Vascular  XDD:398
# 10X302_8:CATGCCTCAACCCGCA  7.0  10x Chromium 3' v3         Vascular  XDD:398
# 10X302_8:CCTTTGGCAACGATTC  7.0  10x Chromium 3' v3         Vascular  XDD:398
#
#                            sampleID         Region      Sex Subdivision  \
# CellID
# 10X89_1:AAACGGGAGGCTACGA    10X89_1  Telencephalon  Unknown      Cortex
# 10X89_1:ACGAGGAAGAGCCTAG    10X89_1  Telencephalon  Unknown      Cortex
# 10X89_1:ACGCCAGTCGATAGAA    10X89_1  Telencephalon  Unknown      Cortex
# 10X89_1:CCGGGATCAGACACTT    10X89_1  Telencephalon  Unknown      Cortex
# 10X89_1:CGACTTCTCCCACTTG    10X89_1  Telencephalon  Unknown      Cortex
# ...                             ...            ...      ...         ...
# 10X302_7:AGAGAATAGAGGATCC  10X302_7       Midbrain  Unknown    Midbrain
# 10X302_8:AAGCCATTCCACCTCA  10X302_8       Midbrain  Unknown    Midbrain
# 10X302_8:ACGGTTAGTTAGGCCC  10X302_8       Midbrain  Unknown    Midbrain
# 10X302_8:CATGCCTCAACCCGCA  10X302_8       Midbrain  Unknown    Midbrain
# 10X302_8:CCTTTGGCAACGATTC  10X302_8       Midbrain  Unknown    Midbrain
#
#                           Subregion    Tissue     Race  Stage      PMI  \
# CellID
# 10X89_1:AAACGGGAGGCTACGA     Cortex    Cortex  Unknown  Fetal  Unknown
# 10X89_1:ACGAGGAAGAGCCTAG     Cortex    Cortex  Unknown  Fetal  Unknown
# 10X89_1:ACGCCAGTCGATAGAA     Cortex    Cortex  Unknown  Fetal  Unknown
# 10X89_1:CCGGGATCAGACACTT     Cortex    Cortex  Unknown  Fetal  Unknown
# 10X89_1:CGACTTCTCCCACTTG     Cortex    Cortex  Unknown  Fetal  Unknown
# ...                             ...       ...      ...    ...      ...
# 10X302_7:AGAGAATAGAGGATCC  Midbrain  Midbrain  Unknown  Fetal  Unknown
# 10X302_8:AAGCCATTCCACCTCA  Midbrain  Midbrain  Unknown  Fetal  Unknown
# 10X302_8:ACGGTTAGTTAGGCCC  Midbrain  Midbrain  Unknown  Fetal  Unknown
# 10X302_8:CATGCCTCAACCCGCA  Midbrain  Midbrain  Unknown  Fetal  Unknown
# 10X302_8:CCTTTGGCAACGATTC  Midbrain  Midbrain  Unknown  Fetal  Unknown
#
#                           Hemisphere Library cluster_main
# CellID
# 10X89_1:AAACGGGAGGCTACGA           A   scRNA       Others
# 10X89_1:ACGAGGAAGAGCCTAG           A   scRNA       Others
# 10X89_1:ACGCCAGTCGATAGAA           A   scRNA       Others
# 10X89_1:CCGGGATCAGACACTT           A   scRNA       Others
# 10X89_1:CGACTTCTCCCACTTG           A   scRNA       Others
# ...                              ...     ...          ...
# 10X302_7:AGAGAATAGAGGATCC          A   scRNA       Others
# 10X302_8:AAGCCATTCCACCTCA          A   scRNA       Others
# 10X302_8:ACGGTTAGTTAGGCCC          A   scRNA       Others
# 10X302_8:CATGCCTCAACCCGCA          A   scRNA       Others
# 10X302_8:CCTTTGGCAACGATTC          A   scRNA       Others
#
# [1665937 rows x 16 columns]

# %%
sum(a.obs.index.duplicated())
# Out:
# 0

# %%
a.obs.Tissue.value_counts()
# Out:
# Forebrain                195398
# Mesencephalon            163064
# Cortex                   149766
# Cerebellum               142362
# Medulla                  127683
# Thalamus                 109783
# Striatum                  95228
# Brain                     85999
# Pons                      62564
# Subcortical forebrain     54002
# Hindbrain                 49456
# Hypothalamus              46667
# Dorsal midbrain           42931
# Hippocampus               35157
# Diencephalon              34579
# Midbrain                  33639
# Pons/Cereb                33488
# Subcortex                 28814
# Frontotemporal cortex     22270
# Lower cortex              18304
# Ventral midbrain          16800
# Tel/diencephalon          16797
# Forebrain cortex          15788
# Pons/Medulla              13782
# Upper cortex              13486
# Occipital cortex          13353
# Caudate-Putamen           13184
# Enthorinal cortex         10839
# Telencephalon              7052
# Cortical hem               6901
# Head                       6801
# Name: Tissue, dtype: int64

# %%
a.obs.groupby(['Region','Subdivision']).size()
# Out:
# Region         Subdivision
# Brain          Brain                   85999
# Cerebellum     Cerebellum             142362
# Diencephalon   Diencephalon            34579
#                Hypothalamus            46667
#                Thalamus               109783
# Forebrain      Forebrain              212195
#                Subcortex              102368
# Head           Head                     6801
# Hindbrain      Hindbrain               63238
# Medulla        Medulla                127683
# Midbrain       Midbrain               196703
#                Midbrain dorsal         42931
#                Midbrain ventral        16800
# Pons           Pons                    96052
# Telencephalon  Caudate+Putamen         13184
#                Cortex                 145113
#                Cortex entorhinal       10839
#                Cortex frontal          22270
#                Cortex hemisphere A      7242
#                Cortex hemisphere B     13199
#                Cortex occipital        13353
#                Cortex parietal         13486
#                Cortex temporal         18304
#                Cortical hem             6901
#                Hippocampus             15605
#                Striatum                95228
#                Telencephalon            7052
# dtype: int64

# %%
a.obs.groupby(['cluster_main','cluster_original']).size()
# Out:
# cluster_main  cluster_original
# Ext           Neuron              561754
#               Neuronal IPC        110260
# Glioblast     Glioblast           132420
# MG            Immune                8102
# Neural crest  Neural crest           871
# Neuroblast    Neuroblast          285699
# OD            Oligo                 6190
# Others        Erythrocyte           8958
#               Fibroblast           19161
#               Placodes               873
#               Vascular             11741
# RG            Radial glia         519908
# dtype: int64

# %%
# Add genes
df = pd.DataFrame(genes)
df.columns = ['gene']
df.set_index('gene', inplace=True)
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [marker-DsRed, marker-Cherry, marker-GFP, marker-Tomato, marker-cre, marker-CFP, marker-mOrange, marker-HcRed, marker-RFP, transgen-Cas9, marker-EGFP, marker-WPRE, Malat1_gRNA10, Malat1_gRNA11, Malat1_gRNA12, Malat1_gRNA13, Malat1_gRNA14, Malat1_gRNA15, Malat1_gRNA16, Malat1_gRNA17, marker-YFP, DDX11L1, WASH7P, MIR6859-1, MIR1302-2, OR4G4P, OR4G11P, CICP27, AL627309.6, AL627309.7, AL627309.5, RNU6-1100P, AL627309.4, FO538757.1, WASH9P, MIR6859-2, AP006222.1, AP006222.2, RPL23AP24, AL732372.2, WBP1LP7, CICP7, AL732372.3, U6, AL669831.3, MTND2P28, AC114498.2, MTCO2P12, MTATP8P1, MTATP6P1, MTCO3P12, WBP1LP6, OR4F16, CICP3, AL669831.1, RNU6-1199P, AL669831.2, LINC01409, AL669831.6, AL669831.4, FAM87B, LINC01128, LINC00115, AL669831.7, FAM41C, TUBB8P11, AL669831.5, AL645608.6, AL645608.2, AL645608.4, LINC02593, SAMD11, NOC2L, KLHL17, PLEKHN1, PERM1, AL645608.7, HES4, ISG15, AL645608.3, AL645608.1, AGRN, AL645608.5, AL390719.1, AL645608.8, RNF223, C1orf159, AL390719.3, LINC01342, MIR200B, MIR200A, MIR429, AL390719.2, TTLL10-AS1, TTLL10, TNFRSF18, TNFRSF4, SDF4, B3GALT6, C1QTNF12, ...]
#
# [59480 rows x 0 columns]

# %%
a.var = df
a.var_names_make_unique()
# Out:
# /home/sonic/miniconda3/envs/scvi-env/lib/python3.9/site-packages/anndata/utils.py:111: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(

# %%
list(a.var.index[0:22])
# Out:
# ['marker-DsRed',
#  'marker-Cherry',
#  'marker-GFP',
#  'marker-Tomato',
#  'marker-cre',
#  'marker-CFP',
#  'marker-mOrange',
#  'marker-HcRed',
#  'marker-RFP',
#  'transgen-Cas9',
#  'marker-EGFP',
#  'marker-WPRE',
#  'Malat1_gRNA10',
#  'Malat1_gRNA11',
#  'Malat1_gRNA12',
#  'Malat1_gRNA13',
#  'Malat1_gRNA14',
#  'Malat1_gRNA15',
#  'Malat1_gRNA16',
#  'Malat1_gRNA17',
#  'marker-YFP',
#  'DDX11L1']

# %%
genes_to_remove = list(a.var.index[0:21])
genes_to_keep = list(a.var.index[21:])
a = a[:,genes_to_keep]

# %%
a.var
# Out:
# Empty DataFrameView
# Columns: []
# Index: [DDX11L1, WASH7P, MIR6859-1, MIR1302-2, OR4G4P, OR4G11P, CICP27, AL627309.6, AL627309.7, AL627309.5, RNU6-1100P, AL627309.4, FO538757.1, WASH9P, MIR6859-2, AP006222.1, AP006222.2, RPL23AP24, AL732372.2, WBP1LP7, CICP7, AL732372.3, U6, AL669831.3, MTND2P28, AC114498.2, MTCO2P12, MTATP8P1, MTATP6P1, MTCO3P12, WBP1LP6, OR4F16, CICP3, AL669831.1, RNU6-1199P, AL669831.2, LINC01409, AL669831.6, AL669831.4, FAM87B, LINC01128, LINC00115, AL669831.7, FAM41C, TUBB8P11, AL669831.5, AL645608.6, AL645608.2, AL645608.4, LINC02593, SAMD11, NOC2L, KLHL17, PLEKHN1, PERM1, AL645608.7, HES4, ISG15, AL645608.3, AL645608.1, AGRN, AL645608.5, AL390719.1, AL645608.8, RNF223, C1orf159, AL390719.3, LINC01342, MIR200B, MIR200A, MIR429, AL390719.2, TTLL10-AS1, TTLL10, TNFRSF18, TNFRSF4, SDF4, B3GALT6, C1QTNF12, AL162741.1, UBE2J2, LINC01786, SCNN1D, ACAP3, MIR6726, PUSL1, INTS11, MIR6727, AL139287.1, CPTP, TAS1R3, DVL1, MIR6808, MXRA8, AURKAIP1, NDUFB4P8, CCNL2, MRPL20-AS1, MRPL20, RN7SL657P, ...]
#
# [59459 rows x 0 columns]

# %%
# a1 = a[a.obs.Subdivision=='Cortex frontal']
# a1.obs['Brain_Region'] = 'Cortex frontal'
# a1.obs['Dataset'] = 'BraunCortexFrontal'
# sc.pp.filter_cells(a1, min_counts=50)
# a1.write('/home/sonic/scData/anndata/HCA_Braun.subset_cortexFrontal.h5ad')

# %%
# a1 = a[a.obs.Subdivision=='Cortex']
# a1.obs['Brain_Region'] = 'Cortex'
# a1.obs['Dataset'] = 'BraunCortex'
# sc.pp.filter_cells(a1, min_counts=50)
# a1.write('/home/sonic/scData/anndata/HCA_Braun.subset_cortex.h5ad')

# %%
# a1 = a[a.obs.Region=='Telencephalon']
# a1.obs['Brain_Region'] = 'Telencephalon'
# a1.obs['Dataset'] = 'BraunTelencephalon'
# sc.pp.filter_cells(a1, min_counts=50)
# a1.write('/home/sonic/scData/anndata/HCA_Braun.subset_Telencephalon.h5ad')

# %%
# a1 = a[a.obs.Subdivision=='Striatum']
# a1.obs['Brain_Region'] = 'Striatum'
# a1.obs['Dataset'] = 'BraunStriatum'
# sc.pp.filter_cells(a1, min_counts=50)
# a1.write('/home/sonic/scData/anndata/HCA_Braun.subset_Striatum.h5ad')

# %%
sc.pp.subsample(a, fraction=0.3, random_state=42)

# %%
a
# Out:
# AnnData object with n_obs × n_vars = 499781 × 59459
#     obs: 'Age', 'Assay', 'cluster_original', 'batch', 'sampleID', 'Region', 'Sex', 'Subdivision', 'Subregion', 'Tissue', 'Race', 'Stage', 'PMI', 'Hemisphere', 'Library', 'cluster_main'

# %%
sc.pp.filter_genes(a, min_cells=1)
a
# Out:
# AnnData object with n_obs × n_vars = 499781 × 46461
#     obs: 'Age', 'Assay', 'cluster_original', 'batch', 'sampleID', 'Region', 'Sex', 'Subdivision', 'Subregion', 'Tissue', 'Race', 'Stage', 'PMI', 'Hemisphere', 'Library', 'cluster_main'
#     var: 'n_cells'

# %%
# sc.pp.filter_cells(a, min_counts=200)
# a

# %%
a.obs['Brain_Region'] = a.obs['Subdivision']
a.obs['Dataset'] = 'Braun'
a.write('/home/sonic/scData/anndata/HCA_Braun_minCell_1_pct30.h5ad')

# %%
a.obs.Subdivision.value_counts()
# Out:
# Forebrain              63753
# Midbrain               58885
# Cortex                 43757
# Cerebellum             42856
# Medulla                38442
# Thalamus               32956
# Subcortex              30800
# Pons                   28741
# Striatum               28687
# Brain                  25650
# Hindbrain              18863
# Hypothalamus           14076
# Midbrain dorsal        12788
# Diencephalon           10318
# Cortex frontal          6641
# Cortex temporal         5435
# Midbrain ventral        5132
# Hippocampus             4649
# Cortex occipital        3985
# Cortex hemisphere B     3944
# Caudate+Putamen         3931
# Cortex parietal         3921
# Cortex entorhinal       3199
# Telencephalon           2140
# Cortex hemisphere A     2134
# Cortical hem            2057
# Head                    2041
# Name: Subdivision, dtype: int64
